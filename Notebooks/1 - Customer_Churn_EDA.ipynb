# %% [markdown]
# # **Python Tasks:**

# %% [markdown]
# **1️⃣ Load dataset, check shape & info**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df =pd.read_csv('/content/projectk.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %% [markdown]
# **2️⃣ Churn distribution (countplot)**

# %%
sns.countplot(x='Churn', data=df)
plt.title("Distribution of Churn")
plt.show()

# %% [markdown]
# **3️⃣ Tenure vs Churn (boxplot)**

# %%
sns.boxplot(x='Churn' , y='tenure', data=df)
plt.xlabel("Churn")
plt.ylabel("Tenure")
plt.title("Tenure vs Churn")
plt.show()

# %% [markdown]
# **4️⃣ MonthlyCharges vs Churn**

# %%
sns.boxplot(x='Churn' , y='MonthlyCharges', data=df)
plt.xlabel("Churn")
plt.ylabel("MonthlyCharges")
plt.title("MonthlyCharges vs Churn")
plt.show()

# %% [markdown]
# **5️⃣ Contract type vs Churn (bar chart)**

# %%
sns.barplot(x='Contract' , y='Churn', data=df)
plt.xlabel("Contract ")
plt.ylabel("Churn")
plt.title("Contract  vs Churn")
plt.show()

# %% [markdown]
# **6️⃣ Correlation heatmap**

# %%
numeric_df = df.select_dtypes(include=['number'])

# %%
corr = numeric_df.corr()

# %%
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # **BUSINESS INSIGHTS**

# %% [markdown]
# **(1) Long-term customers churn less ?**

# %% [markdown]
# Yes the long-term customers are less to compare with monthly base because the long-term customers amout is fixed and they don't chance to move the other service

# %% [markdown]
# **(2) Month-to-month contracts have high churn ?**

# %% [markdown]
# Yes the Month-to-month customers have the high chance of churn change the other service they tenure is short so there have high to change the other service compare to long-term customers

# %% [markdown]
# **(3) High monthly charges increase churn risk ?**

# %% [markdown]
# Yes it's correct high monthly chargers increase the high risk of churn becuase the customer feel its high price compare to other services

# %% [markdown]
# **(4) Short tenure customers are more vulnerable**

# %% [markdown]
# yes the short tenure customers are more valuable because the count of short tenure customers are high they only generated the high revenue in the company compare to the long tenure customers
